# %%
def stateless_reply(prompt: str) -> str:
    return f"(Some llm response minicking the model's output., {prompt})"

# %%
print(stateless_reply("Hello from first-learn!"))
# Out:
# (Some llm response minicking the model's output., Hello from first-learn!)

# %%
def stateless_chatgpt_demo(prompt: str) -> str:
    from openai import OpenAI
    import os

    client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.environ.get("OPENROUTER_API_KEY")
    )

    completion = client.responses.create(
    model="~openai/gpt-4o-mini",
    messages=[
        {
        "role": "user",
        "content": "What is the meaning of life?"
        }
    ]
    )

    return completion.output_text

stateless_chatgpt_demo("What is the meaning of life?")
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[17], line 22
#      18     )
#      19
#      20     return completion.output_text
#      21
# ---> 22 stateless_chatgpt_demo("What is the meaning of life?")
#      23
#
# Cell In[17], line 5, in stateless_chatgpt_demo(prompt)
#       1 def stateless_chatgpt_demo(prompt: str) -> str:
#       2     from openai import OpenAI
#       3     import os
#       4
# ----> 5     client = OpenAI(
#       6     base_url="https://openrouter.ai/api/v1",
#       7     api_key=os.environ.get("OPENROUTER_API_KEY")
#       8     )
#
# ...

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("GROQ_API_KEY")

if not api_key:
    raise ValueError("GROQ_API_KEY is missing from the .env file")

client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=api_key,
)

def stateless_chatgpt_demo(prompt: str) -> str:
    completion = client.chat.completions.create(
        model="openai/gpt-oss-120b",
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        temperature=0.7,
    )

    return completion.choices[0].message.content


answer = stateless_chatgpt_demo("Who is the best cricketer in india ? Return only the name of the player, no other text.")
print(answer)
# Out:
# Virat Kohli
